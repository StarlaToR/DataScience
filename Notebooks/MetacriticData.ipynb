# %% [markdown]
# Video Game Analysis

# %% [markdown]
# Data Prepocessing

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

metacritic = pd.read_csv("../Dataset/dataset_metacritic_scraper_2025-02-15.csv", sep=',', decimal='.')
metacritic_cleaned = metacritic.drop_duplicates()
metacritic_cleaned = metacritic_cleaned.dropna(subset=['genres', 'metascore'])
metacritic_cleaned['metascore'] = pd.to_numeric(metacritic_cleaned['metascore'], errors='coerce')
metacritic_cleaned['userscore'] = pd.to_numeric(metacritic_cleaned['userscore'], errors='coerce')
# Out:
# C:\Users\mateo\AppData\Local\Temp\ipykernel_2852\3191426262.py:5: DtypeWarning: Columns (2,155,162,163,170,171,178,179,186,195,196,197,198) have mixed types. Specify dtype option on import or set low_memory=False.
#   metacritic = pd.read_csv("../Dataset/dataset_metacritic_scraper_2025-02-15.csv", sep=',', decimal='.')

# %% [markdown]
# Graphs

# %%
HighFrequencyGenres = metacritic_cleaned["genres"].value_counts().head(20).index
HighFrequencyGenres = metacritic_cleaned[metacritic_cleaned["genres"].isin(HighFrequencyGenres)]
UserScoreMeanPerGenre = HighFrequencyGenres.groupby("genres")["metascore"].mean().sort_values(ascending=False).head(10)

# Position de base sur l'axe X
x = np.arange(len(UserScoreMeanPerGenre.index))

# Largeur des barres
largeur = 0.35

# Création du graphique
plt.bar(UserScoreMeanPerGenre.index, UserScoreMeanPerGenre.values, color = 'skyblue')
plt.xticks(rotation=90)
plt.xlabel("Genres")
plt.ylabel("Mean Metacritic Score")
plt.title("Top 10 mean Metacritic score per genre")

plt.figure()
# Out:
# Text(0.5, 1.0, 'Mean Metacritic score per genre')
